# %%
import json
from pprint import pprint

with open('patternswiki.json', 'r') as json_data:
    d = json.loads(json_data.read())
    json_data.close()
#     pprint(d)

# %%
from collections import Counter
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
from collections import Counter, OrderedDict
def word_count(fname):
        with open(fname) as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("predicatepatterns.txt"))

d=word_count("predicatepatterns.txt")
type(df)
d=OrderedDict(d.most_common())
df = pd.DataFrame.from_dict(d, orient='index').reset_index()
df.head(15)
# word_count("predicatepatterns.txt")

# d={'http://wikiba.se/ontology#language': 88072, 'http://www.wikidata.org/prop/direct/P31': 63927, 'http://www.w3.org/2000/01/rdf-schema#label': 47823, 'http://www.wikidata.org/prop/direct/P18': 35315, 'http://www.wikidata.org/prop/direct/P625': 28912, 'http://www.wikidata.org/prop/direct/P279': 27832, 'http://schema.org/description': 22334, 'http://schema.org/about': 14825, 'http://www.wikidata.org/prop/direct/P373': 12711, 'http://wikiba.se/ontology#cornerSouthWest': 12057, 'http://wikiba.se/ontology#cornerNorthEast': 12057, 'http://www.wikidata.org/prop/direct/P131': 11717, 'http://www.wikidata.org/prop/direct/P17': 10803, 'http://wikiba.se/ontology#qualifier': 9824, 'http://schema.org/isPartOf': 8408}
# x= d.keys()
# y=d.values()
# fig, ax = plt.subplots()    
# width = 0.75 # the width of the bars 
# ind = np.arange(len(y))  # the x locations for the groups
# ax.barh(ind, y, width, color="blue")
# ax.set_yticks(ind+width/2)
# ax.set_yticklabels(x, minor=False)
# plt.title('title')
# plt.xlabel('x')
# plt.ylabel('y') 
# for i, v in enumerate(y):
#     ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')
# plt.show()
# Out:
# Number of words in the file : Counter({'http://wikiba.se/ontology#language': 88072, 'http://www.wikidata.org/prop/direct/P31': 63927, 'http://www.w3.org/2000/01/rdf-schema#label': 47823, 'http://www.wikidata.org/prop/direct/P18': 35315, 'http://www.wikidata.org/prop/direct/P625': 28912, 'http://www.wikidata.org/prop/direct/P279': 27832, 'http://schema.org/description': 22334, 'http://schema.org/about': 14825, 'http://www.wikidata.org/prop/direct/P373': 12711, 'http://wikiba.se/ontology#cornerSouthWest': 12057, 'http://wikiba.se/ontology#cornerNorthEast': 12057, 'http://www.wikidata.org/prop/direct/P131': 11717, 'http://www.wikidata.org/prop/direct/P17': 10803, 'http://wikiba.se/ontology#qualifier': 9824, 'http://schema.org/isPartOf': 8408, 'http://schema.org/inLanguage': 8302, 'http://www.wikidata.org/prop/direct/P50': 7879, 'http://www.wikidata.org/prop/direct/P921': 6172, 'http://www.wikidata.org/prop/direct/P106': 5289, 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type': 5104, 'htt
# ...
